# %% [markdown]
# # Stable Baselines3 - Training, Saving and Loading
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# !apt-get update && apt-get install swig cmake
# !conda install -y swig
# !pip install box2d-py
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ismail/anaconda3
#
#   added / updated specs:
#     - swig
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     swig-4.0.2                 |       h295c915_4         1.1 MB
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   swig               pkgs/main/linux-64::swig-4.0.2-h295c915_4 None
#
#
#
# Downloading and Extracting Packages
# swig-4.0.2           | 1.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
# Collecting box2d-py
#   Using cached box2d-py-2.3.8.tar.gz (374 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp39-cp39-linux_x86_64.whl size=495077 sha256=a16d5be1af66030afadec97697baf26c084c49a907b780ec699c6297bf23d795
#   Stored in directory: /home/ismail/.cache/pip/wheels/a0/6a/54/2383a12859109612796c6b235ff6704a82b99caa4308ca0b43
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will use Lunar Lander environment.
#
# "Landing outside landing pad is possible. Fuel is infinite, so an agent can learn to fly and then land on its first attempt. Four discrete actions available: do nothing, fire left orientation engine, fire main engine, fire right orientation engine. "
#
# Lunar Lander environment: [https://gymnasium.farama.org/environments/box2d/lunar_lander/](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ![Lunar Lander](https://cdn-images-1.medium.com/max/960/1*f4VZPKOI0PYNWiwt0la0Rg.gif)
#
#
# We chose the MlpPolicy because input of Lunar Lander is a feature vector, not images.
#
# The type of action to use (discrete/continuous) will be automatically deduced from the environment action space

# %%
model = DQN(
    "MlpPolicy",
    "LunarLander-v2",
    verbose=1,
    exploration_final_eps=0.1,
    target_update_interval=250,
)
# Out:
# Using cpu device
# Creating environment from the given name 'LunarLander-v2'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# We load a helper function to evaluate the agent:

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Let's evaluate the un-trained agent, this should be a random agent.

# %%
# Separate env for evaluation
eval_env = gym.make("LunarLander-v2")

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    deterministic=True,
)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /home/ismail/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-374.39 +/- 99.22309285223726

# %% [markdown]
# ## Train the agent and save it
#
# Warning: this may take a while

# %%
# Train the agent
model.learn(total_timesteps=int(1e5))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 936      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 410      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 979      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 839      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 981      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 994      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1008     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1015     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1017     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1023     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1015     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1024     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1023     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1024     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1019     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1017     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1020     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1014     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1017     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.385    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1019     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1021     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1024     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1025     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1027     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1022     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.201    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1009     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.173    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1004     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.135    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 999      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1001     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1002     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 998      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 987      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 981      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 981      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 980      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 979      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 984      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 992      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 995      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 999      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1002     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1002     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1002     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1002     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1002     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1002     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1000     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 999      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 997      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 994      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 992      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 18065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 987      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 18477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 986      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 18846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 985      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 19187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 973      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 965      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 962      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 20270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 959      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 20634    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 953      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 21003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 945      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 21318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 938      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 21707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 935      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 22084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 935      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 22497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 933      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 22883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 933      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 23266    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 931      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 23629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 928      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 23916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 929      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 24344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 933      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 24690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 937      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 25059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 939      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 25422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 940      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 25780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 941      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 26140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 942      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 26555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 944      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 26891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 945      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 27230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 947      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 27582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 949      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 27969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 952      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 28361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 954      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 28729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 957      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 29046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 961      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 29460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 964      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 29825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 967      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 30132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 971      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 30613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 974      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 30976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 978      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 31348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 982      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 31727    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 985      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 32115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 989      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 32538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 992      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 32917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 996      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 33304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 998      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 33651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1001     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 33993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1001     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 34346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1003     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 34755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1004     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 35063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1006     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 35441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1006     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 35880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1006     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 36225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1005     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 36567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1004     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 36916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1006     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 37243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1007     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 37587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1008     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 37997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1008     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 38314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1010     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 38664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1011     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 39052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1011     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 39368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1012     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 39703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1014     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 39994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1014     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 40453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1014     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 40893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1016     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 41276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1017     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 41589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1016     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 41951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1017     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 42348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1018     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 42671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1019     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 42984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1021     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 43343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1023     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 43680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1023     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 44107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1025     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 44473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1026     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 44877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 1027     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 45296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 1029     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 45608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1031     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 45893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 1032     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 46228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 1033     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 46594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 1034     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 46993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 1034     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 47317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1034     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 47683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 1034     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 48063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 1032     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 48409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 1031     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 48800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 1032     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 49163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1032     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 49502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 1033     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 49895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 1025     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 50165    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 1012     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 50457    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81     |
# |    n_updates        | 114      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 991      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 50838    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -225     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 960      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 51432    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 357      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -242     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 942      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 51860    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 464      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -258     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 923      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 52275    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.965    |
# |    n_updates        | 568      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -275     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 904      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 52654    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 663      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -303     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 869      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 53189    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.55     |
# |    n_updates        | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | -309     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 838      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 53809    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.945    |
# |    n_updates        | 952      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -306     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 704      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 56486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.74     |
# |    n_updates        | 1621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -306     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 533      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 60486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.84     |
# |    n_updates        | 2621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | -305     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 445      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 64486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.674    |
# |    n_updates        | 3621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | -307     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 388      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 68486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1        |
# |    n_updates        | 4621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | -306     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 336      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 72486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 5621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -305     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 307      |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 76486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.832    |
# |    n_updates        | 6621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 333      |
# |    ep_rew_mean      | -295     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 293      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 79856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.864    |
# |    n_updates        | 7463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 367      |
# |    ep_rew_mean      | -292     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 275      |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 83718    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 8429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | -281     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 259      |
# |    time_elapsed     | 338      |
# |    total_timesteps  | 87718    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 9429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | -274     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 250      |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 91209    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.774    |
# |    n_updates        | 10302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | -269     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 244      |
# |    time_elapsed     | 383      |
# |    total_timesteps  | 93877    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.791    |
# |    n_updates        | 10969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 490      |
# |    ep_rew_mean      | -256     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 238      |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 97385    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.939    |
# |    n_updates        | 11846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 509      |
# |    ep_rew_mean      | -243     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 235      |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 99723    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.67     |
# |    n_updates        | 12430    |
# ----------------------------------

# %% [markdown]
# ## Load the trained agent

# %%
model = DQN.load("dqn_lunar")

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
