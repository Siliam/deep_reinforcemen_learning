# %%
! pip install 'stable-baselines3[extra]'
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 2.4 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pandas in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: torch>=1.11 in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: numpy>=1.20 in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (1.25.0)
# Requirement already satisfied: matplotlib in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (3.5.1)
# Collecting gymnasium==0.28.1
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      |████████████████████████████████| 925 kB 9.6 MB/s eta 0:00:01
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      |████████████████████████████████| 61.7 MB 13.8 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: pillow in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: rich in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (13.4.2)
# Collecting autorom[accept-rom-license]~=0.6.0
#   Using cached AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: psutil in /home/ismail/anaconda3/lib/python3.9/site-packages (from stable-baselines3[extra]) (5.8.0)
# Collecting pygame
#   Downloading pygame-2.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 14.6 MB/s eta 0:00:01
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 9.8 MB/s eta 0:00:01
# Collecting shimmy[atari]~=0.2.1
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.6.3)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: click in /home/ismail/anaconda3/lib/python3.9/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in /home/ismail/anaconda3/lib/python3.9/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.27.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      |████████████████████████████████| 434 kB 11.5 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: zipp>=0.5 in /home/ismail/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium==0.28.1->stable-baselines3[extra]) (3.7.0)
# Collecting ale-py~=0.8.1
#   Downloading ale_py-0.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 3.7 MB/s eta 0:00:01
# Collecting importlib-resources
#   Downloading importlib_resources-6.0.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ismail/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.33.0)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 7.3 MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26 in /home/ismail/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      |████████████████████████████████| 304 kB 10.6 MB/s eta 0:00:01
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.56.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 8.0 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 11.7 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /home/ismail/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (61.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ismail/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 10.5 MB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3<2.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ismail/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ismail/anaconda3/lib/python3.9/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ismail/anaconda3/lib/python3.9/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.3)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 11.4 MB/s eta 0:00:01
# Requirement already satisfied: triton==2.0.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.4.0.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: filelock in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.14.3)
# Requirement already satisfied: jinja2 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.11.3)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.4.91)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (10.2.10.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (10.9.0.58)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.10.3.66)
# Requirement already satisfied: sympy in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (1.10.1)
# Requirement already satisfied: networkx in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.7.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ismail/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.101)
# Requirement already satisfied: cmake in /home/ismail/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (3.26.4)
# Requirement already satisfied: lit in /home/ismail/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (16.0.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ismail/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11->stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/ismail/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ismail/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ismail/anaconda3/lib/python3.9/site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ismail/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ismail/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.2.1)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446659 sha256=a92aa3e789afc1ea5191c5adce336975f2f22f29f48eccb84cb3139b73e3bef2
#   Stored in directory: /home/ismail/.cache/pip/wheels/b1/1f/f7/2da07cf4f81ea264bdaf043028749d88fe0c2227134a22cf80
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: oauthlib, jax-jumpy, farama-notifications, requests-oauthlib, importlib-resources, gymnasium, google-auth, tensorboard-data-server, shimmy, protobuf, grpcio, google-auth-oauthlib, AutoROM.accept-rom-license, autorom, ale-py, absl-py, tensorboard, stable-baselines3, pygame, opencv-python
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.33.0
#     Uninstalling google-auth-1.33.0:
#       Successfully uninstalled google-auth-1.33.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-storage 1.31.0 requires google-auth<2.0dev,>=1.11.0, but you have google-auth 2.22.0 which is incompatible.
# google-cloud-core 1.7.1 requires google-auth<2.0dev,>=1.24.0, but you have google-auth 2.22.0 which is incompatible.
# google-api-core 1.25.1 requires google-auth<2.0dev,>=1.21.1, but you have google-auth 2.22.0 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.6.1 absl-py-1.4.0 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 google-auth-2.22.0 google-auth-oauthlib-1.0.0 grpcio-1.56.2 gymnasium-0.28.1 importlib-resources-6.0.0 jax-jumpy-1.0.0 oauthlib-3.2.2 opencv-python-4.8.0.74 protobuf-4.23.4 pygame-2.5.0 requests-oauthlib-1.3.1 shimmy-0.2.1 stable-baselines3-2.0.0 tensorboard-2.13.0 tensorboard-data-server-0.7.1

# %%
import gymnasium as gym

# %%
from stable_baselines3 import PPO

# %%
env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    # VecEnv resets automatically
    # if done:
    #   obs = env.reset()

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    fps             | 390      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.8        |
# |    ep_rew_mean          | 25.8        |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008299422 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00597    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.4         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 51          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.5        |
# |    ep_rew_mean          | 36.5        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008965081 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0677      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 35.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | 49.5        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 4           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010605205 |
# |    clip_fraction        | 0.084       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 61          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 64.2       |
# |    ep_rew_mean          | 64.2       |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 5          |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00695563 |
# |    clip_fraction        | 0.0602     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.267      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.7       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0162    |
# |    value_loss           | 68.7       |
# ----------------------------------------
# /home/ismail/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:234: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
model = PPO("MlpPolicy", "CartPole-v1").learn(10_000)
